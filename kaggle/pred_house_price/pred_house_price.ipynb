# %%
import pandas as pd
house=pd.read_csv('train.csv')
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house=house.loc[:,house.dtypes!='object'].dropna(how='any')
y_train=house['SalePrice']
del house['SalePrice']
X_train=house
print(X_train.shape,y_train.shape)
# Out:
# (1121, 37) (1121,)

# %%
house=pd.read_csv('test.csv')
house.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
house=house.loc[:,house.dtypes!='object'].dropna(how='any')
X_test=house
print(X_train.shape)
# Out:
# (1121, 37)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_test=lr.predict(X_test)
y_test
# Out:
# array([ 117706.22457225,  110072.26690164,  172769.60412765, ...,
#          56425.60652425,  166318.34419451,  257641.81074099])

# %%
data=list(zip(house['Id'],y_test))
data
# Out:
# [(1461, 117706.22457225213),
#  (1462, 110072.26690163673),
#  (1463, 172769.60412764526),
#  (1464, 199392.4081409041),
#  (1465, 198000.58403495169),
#  (1466, 182086.45503688266),
#  (1468, 171825.12883315247),
#  (1469, 206627.24253140279),
#  (1470, 114760.12927005079),
#  (1471, 205833.78829135379),
#  (1472, 115245.56163396232),
#  (1473, 91317.775037298561),
#  (1474, 154023.47522975469),
#  (1475, 114471.22886163625),
#  (1476, 318468.59859064763),
#  (1477, 251790.57433246152),
#  (1478, 296516.42009326193),
#  (1479, 276002.83706813358),
#  (1480, 407913.71423946117),
#  (1481, 296431.21044855734),
#  (1482, 215353.23102401855),
#  (1483, 172733.27505957836),
#  (1484, 173031.02714315907),
#  (1485, 199946.82386004349),
#  (1486, 209254.92577003554),
#  (1487, 294899.78629378165),
#  (1488, 264794.80409209878),
#  (1489, 182691.93304841127),
#  (1490, 229969.86476985906),
#  (1491, 211928.33293786185),
#  (1492, 88759.742654974805),
#  (1493, 223937.69799728045),
# ...

# %%
df = pd.DataFrame(data=data,columns=['Id','SalePrice'])
df
# Out:
#         Id      SalePrice
# 0     1461  117706.224572
# 1     1462  110072.266902
# 2     1463  172769.604128
# 3     1464  199392.408141
# 4     1465  198000.584035
# 5     1466  182086.455037
# 6     1468  171825.128833
# 7     1469  206627.242531
# 8     1470  114760.129270
# 9     1471  205833.788291
# 10    1472  115245.561634
# 11    1473   91317.775037
# 12    1474  154023.475230
# 13    1475  114471.228862
# 14    1476  318468.598591
# 15    1477  251790.574332
# 16    1478  296516.420093
# 17    1479  276002.837068
# 18    1480  407913.714239
# 19    1481  296431.210449
# 20    1482  215353.231024
# 21    1483  172733.275060
# 22    1484  173031.027143
# 23    1485  199946.823860
# 24    1486  209254.925770
# 25    1487  294899.786294
# 26    1488  264794.804092
# 27    1489  182691.933048
# 28    1490  229969.864770
# 29    1491  211928.332938
# ...    ...            ...
# 1116  2879  121866.699536
# 1117  2880   81620.209535
# 1118  2881  136152.396930
# ...

# %%
df.to_csv('submission.csv',index=False)
